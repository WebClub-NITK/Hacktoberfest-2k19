# %%
# Importing Dependencies
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Reading in the image and changing the color format of image because OpenCV show image in BGR while Matplotlib show the image in RGB format
image = cv2.imread('image.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.show()

# %%
# Function for generating the Salt & Pepper type of noise in the image
def salt_n_pepper(img, pad = 101, show = 1):
    img.astype(np.float16, copy = False)
    img = np.multiply(img, (1/255))
    noise = np.random.randint(pad, size = (img.shape[0], img.shape[1], 1))
    img = np.where(noise == 0, 0, img)
    img = np.where(noise == (pad-1), 1, img)
    img = cv2.convertScaleAbs(img, alpha = (255/1))
    return img

# Function to remvoe the salt & pepper noise from the inpout image
def median(img, ksize = 3, title = 'Median Filter Result', show = 1):
    img = cv2.medianBlur(img, ksize)
    return img

# %%
# Generating the Noisy image
noisy_image = salt_n_pepper(image)
plt.imshow(noisy_image)

# %%
# Applying the Median Filter to remove the Noisy image
median_applied_image = median(noisy_image)
plt.imshow(median_applied_image)
